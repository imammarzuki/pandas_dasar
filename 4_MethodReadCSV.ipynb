# %% [markdown]
# <a href="https://colab.research.google.com/github/imammarzuki/pandas_dasar/blob/main/4_MethodReadCSV.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas Series – Menggunakan Method read_csv()

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

# %%
fake_comp = pd.read_csv("drive/MyDrive/pandas_dasar/Data/mock_data_perush.csv", usecols=["nama_perush"])
fake_comp
# Out:
#       nama_perush
# 0        Photobug
# 1    Jabbersphere
# 2         Voonder
# 3           Kimia
# 4       Buzzshare
# 5        Bluezoom
# 6            DabZ
# 7         Tagtune
# 8        Photojam
# 9         Centizu
# 10        Plambee
# 11     Brainverse
# 12     Topicstorm
# 13     Brainverse
# 14          Aimbo
# 15   Thoughtstorm
# 16         Rhybox
# 17           Katz
# 18         Yacero
# 19    Jabberstorm
# 20      Zoonoodle
# 21        Skippad
# 22    Browsedrive
# 23           Vitz
# 24          Kamba
# 25         Meeveo
# 26     Topicstorm
# 27    Browsedrive
# 28        Demivee
# 29        Dynabox
# 30        Myworks
# 31        Gabvine
# 32         Kayveo
# 33      Flipstorm
# 34       Skiptube
# 35        Myworks
# 36       Realcube
# 37        Skinder
# 38         Camido
# 39          Kamba
# 40        Edgetag
# 41         Zooveo
# 42    Topiclounge
# 43          Npath
# 44         Voonyx
# 45          Yodel
# 46          Mynte
# 47           Eare
# 48  Twitterbridge
# ...
