# %% [markdown]
# <a href="https://colab.research.google.com/github/imammarzuki/pandas_dasar/blob/main/33_RetrieveRowIloc.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas DataFrame – Retrieve Row Menggunakan Index Position dengan Method iloc[]

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv("drive/MyDrive/pandas_dasar/Data/jamesbond.csv")

# %%
df.head(10)
# Out:
#                               Film  Year           Actor       Director  \
# 0                           Dr. No  1962    Sean Connery  Terence Young
# 1            From Russia with Love  1963    Sean Connery  Terence Young
# 2                       Goldfinger  1964    Sean Connery   Guy Hamilton
# 3                      Thunderball  1965    Sean Connery  Terence Young
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
# 7             Diamonds Are Forever  1971    Sean Connery   Guy Hamilton
# 8                 Live and Let Die  1973     Roger Moore   Guy Hamilton
# 9      The Man with the Golden Gun  1974     Roger Moore   Guy Hamilton
#
#    Box Office  Budget  Bond Actor Salary
# 0       448.8     7.0                0.6
# 1       543.8    12.6                1.6
# 2       820.4    18.6                3.2
# ...

# %%
df.iloc[4]
# Out:
# Film                 Casino Royale
# Year                          1967
# Actor                  David Niven
# Director                Ken Hughes
# Box Office                   315.0
# Budget                        85.0
# Bond Actor Salary              NaN
# Name: 4, dtype: object

# %%
df.iloc[[4, 7]]
# Out:
#                    Film  Year         Actor      Director  Box Office  Budget  \
# 4         Casino Royale  1967   David Niven    Ken Hughes       315.0    85.0
# 7  Diamonds Are Forever  1971  Sean Connery  Guy Hamilton       442.5    34.7
#
#    Bond Actor Salary
# 4                NaN
# 7                5.8

# %%
df.iloc[4 : 7]
# Out:
#                               Film  Year           Actor       Director  \
# 4                    Casino Royale  1967     David Niven     Ken Hughes
# 5              You Only Live Twice  1967    Sean Connery  Lewis Gilbert
# 6  On Her Majesty's Secret Service  1969  George Lazenby  Peter R. Hunt
#
#    Box Office  Budget  Bond Actor Salary
# 4       315.0    85.0                NaN
# 5       514.2    59.9                4.4
# 6       291.5    37.3                0.6

# %%
#mengembalikan row dari index ke 4 sampai akhir dataframe.
df.iloc[4 :]

#mengembalikan row dari awal dataframe sampai index ke 4.
df.iloc[: 4]
# Out:
#                     Film  Year         Actor       Director  Box Office  \
# 0                 Dr. No  1962  Sean Connery  Terence Young       448.8
# 1  From Russia with Love  1963  Sean Connery  Terence Young       543.8
# 2             Goldfinger  1964  Sean Connery   Guy Hamilton       820.4
# 3            Thunderball  1965  Sean Connery  Terence Young       848.1
#
#    Budget  Bond Actor Salary
# 0     7.0                0.6
# 1    12.6                1.6
# 2    18.6                3.2
# 3    41.9                4.7

# %%
df1 = pd.read_csv("drive/MyDrive/pandas_dasar/Data/jamesbond.csv", index_col="Film")
df1.sort_index(inplace=True)

df1.iloc[:3]
# Out:
#                   Year         Actor         Director  Box Office  Budget  \
# Film
# A View to a Kill  1985   Roger Moore        John Glen       275.2    54.5
# Casino Royale     2006  Daniel Craig  Martin Campbell       581.5   145.3
# Casino Royale     1967   David Niven       Ken Hughes       315.0    85.0
#
#                   Bond Actor Salary
# Film
# A View to a Kill                9.1
# Casino Royale                   3.3
# Casino Royale                   NaN

# %%
df1.iloc[0, [0, 1, 2]]
# Out:
# Year               1985
# Actor       Roger Moore
# Director      John Glen
# Name: A View to a Kill, dtype: object

# %%
#ERROR
df1.iloc[0, [0:2]]
# Out:
#   File "<ipython-input-10-a71b0af87777>", line 2
#     df1.iloc[0, [0:2]]
#                   ^
# SyntaxError: invalid syntax

# %%
#VALID, akan mengembalikan 2 row, dengan 3 kolom (Year, Actor dan Director).
df.iloc[0:2, [0, 1, 2]]
# Out:
#                     Film  Year         Actor
# 0                 Dr. No  1962  Sean Connery
# 1  From Russia with Love  1963  Sean Connery
