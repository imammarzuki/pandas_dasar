# %% [markdown]
# <a href="https://colab.research.google.com/github/imammarzuki/pandas_dasar/blob/main/38_RetrieveRandomData.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Pandas DataFrame – Retrieve Random Data

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd

df = pd.read_csv("drive/MyDrive/pandas_dasar/Data/jamesbond.csv", index_col="Film")
df.sort_index(inplace=True)

# %%
#retrive data random 2 baris
df.sample(n=2)

#sama dengan perintah berikut
# df.sampe(n=2, axis=0)
# df.sampe(n=2, axis="rows")
# df.sampe(n=2, axis="index")
# Out:
#                        Year         Actor         Director  Box Office  \
# Film
# Casino Royale          2006  Daniel Craig  Martin Campbell       581.5
# Never Say Never Again  1983  Sean Connery   Irvin Kershner       380.0
#
#                        Budget  Bond Actor Salary
# Film
# Casino Royale           145.3                3.3
# Never Say Never Again    86.0                NaN

# %%
#retrieve data random sebanyak 30% dari total
df.sample(frac=0.3)
# Out:
#                        Year           Actor         Director  Box Office  \
# Film
# Licence to Kill        1989  Timothy Dalton        John Glen       250.9
# Never Say Never Again  1983    Sean Connery   Irvin Kershner       380.0
# GoldenEye              1995  Pierce Brosnan  Martin Campbell       518.5
# The Living Daylights   1987  Timothy Dalton        John Glen       313.5
# Dr. No                 1962    Sean Connery    Terence Young       448.8
# Casino Royale          1967     David Niven       Ken Hughes       315.0
# Spectre                2015    Daniel Craig       Sam Mendes       726.7
# Die Another Day        2002  Pierce Brosnan     Lee Tamahori       465.4
#
#                        Budget  Bond Actor Salary
# Film
# Licence to Kill          56.7                7.9
# Never Say Never Again    86.0                NaN
# GoldenEye                76.9                5.1
# The Living Daylights     68.8                5.2
# Dr. No                    7.0                0.6
# ...

# %%
#retrieve data dengan 2 kolom random
df.sample(n=2, axis=1)

#sama dengan perintah berikut
#df.sample(n=2, axis="colums")
# Out:
#                                  Box Office           Actor
# Film
# A View to a Kill                      275.2     Roger Moore
# Casino Royale                         581.5    Daniel Craig
# Casino Royale                         315.0     David Niven
# Diamonds Are Forever                  442.5    Sean Connery
# Die Another Day                       465.4  Pierce Brosnan
# Dr. No                                448.8    Sean Connery
# For Your Eyes Only                    449.4     Roger Moore
# From Russia with Love                 543.8    Sean Connery
# GoldenEye                             518.5  Pierce Brosnan
# Goldfinger                            820.4    Sean Connery
# Licence to Kill                       250.9  Timothy Dalton
# Live and Let Die                      460.3     Roger Moore
# Moonraker                             535.0     Roger Moore
# Never Say Never Again                 380.0    Sean Connery
# Octopussy                             373.8     Roger Moore
# ...
